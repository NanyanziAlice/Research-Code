# %%
import networkx as nx
G = nx.Graph()
edges=[(1,2),(1,3),(3,4),(3,5)]
G.add_edges_from(edges)
L = nx.line_graph(G)
L.edges()
# Out:
# [((1, 2), (1, 3)), ((1, 3), (3, 4)), ((1, 3), (3, 5)), ((3, 4), (3, 5))]
