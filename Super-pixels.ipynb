# %%
import matplotlib.pyplot as plt
from skimage.segmentation import slic
from skimage.segmentation import mark_boundaries
from skimage.util import img_as_float
from skimage import io

# %pylab inline
# %matplotlib inline

img = img_as_float(io.imread('Superpixel_3_0.png'))
io.imshow(img)
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
for segs in (10, 50, 100, 300, 500, 1000):
    segments = slic(img, n_segments = segs, sigma = 4)
    fig = plt.figure(figsize=(12,4))
    ax = fig.add_axes([0, 0, 1, 1])
    ax.imshow(mark_boundaries(img, segments)) 
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-bcdf86b30db6> in <module>()
#       3     fig = plt.figure(figsize=(12,4))
#       4     ax = fig.add_axes([0, 0, 1, 1])
# ----> 5     ax.imshow(mark_boundaries(img, segments))
#       6 plt.show()
#
# /usr/lib/python3/dist-packages/skimage/segmentation/boundaries.py in mark_boundaries(image, label_img, color, outline_color, mode, background_label)
#     228         outlines = dilation(boundaries, square(3))
#     229         marked[outlines] = outline_color
# --> 230     marked[boundaries] = color
#     231     return marked
#
# ValueError: shape mismatch: value array of shape (3,) could not be broadcast to indexing result of shape (2901,4)

# %%
# import the necessary packages
from skimage.segmentation import slic
from skimage.segmentation import mark_boundaries
from skimage.util import img_as_float
from skimage import io
import matplotlib.pyplot as plt
import argparse
 
# construct the argument parser and parse the arguments
ap = argparse.ArgumentParser()
ap.add_argument("-i", "--image", required = True, help = "Path to the image")
args = vars(ap.parse_args())
 
# load the image and convert it to a floating point data type
image = img_as_float(io.imread("greyscale.png"))
 
# loop over the number of segments
for numSegments in (100, 200, 300):
    # apply SLIC and extract (approximately) the supplied number
    # of segments
    segments = slic(image, n_segments = numSegments)
 
    # show the output of SLIC
    fig = plt.figure("Superpixels -- %d segments" % (numSegments))
    ax = fig.add_subplot(1, 1, 1)
    ax.imshow(mark_boundaries(image, segments))
    plt.axis("off")
 
# show the plots
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-1-6e67b1dcd5ab> in <module>()
#      24     fig = plt.figure("Superpixels -- %d segments" % (numSegments))
#      25     ax = fig.add_subplot(1, 1, 1)
# ---> 26     ax.imshow(mark_boundaries(image, segments))
#      27     plt.axis("off")
#      28
#
# /usr/lib/python3/dist-packages/skimage/segmentation/boundaries.py in mark_boundaries(image, label_img, color, outline_color, mode, background_label)
#     228         outlines = dilation(boundaries, square(3))
#     229         marked[outlines] = outline_color
# --> 230     marked[boundaries] = color
#     231     return marked
#
# ValueError: shape mismatch: value array of shape (3,) could not be broadcast to indexing result of shape (4272,4)

# %%
from skimage.segmentation import slic, mark_boundaries
from skimage.util import img_as_float
from skimage import io
#from skimage.data import lena
#import slic as slic_wrap # code available at https://github.com/amueller/slic-python
import matplotlib.pyplot as plt


#img = lena()
img = img_as_float(io.imread("greyscale.png"))

#plt.subplot(1,3,1)
#plt.imshow(mark_boundaries(img, slic_wrap.slic_n(img, 40, 10)))
#title('Original version')
plt.subplot(1,3,1)
plt.imshow(mark_boundaries(img, slic(img, 40, 10, sigma=1, enforce_connectivity=False)))
title('skimage version\n enforce_connectivity=False', size=9)
plt.subplot(1,3,2)
plt.imshow(mark_boundaries(img, slic(img, 40, 10, sigma=1, enforce_connectivity=True)))
title('skimage version\n  enforce_connectivity=True', size=9)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-c5e425e7ab4a> in <module>()
#      14 #title('Original version')
#      15 plt.subplot(1,3,1)
# ---> 16 plt.imshow(mark_boundaries(img, slic(img, 40, 10, sigma=1, enforce_connectivity=False)))
#      17 title('skimage version\n enforce_connectivity=False', size=9)
#      18 plt.subplot(1,3,2)
#
# /usr/lib/python3/dist-packages/skimage/segmentation/boundaries.py in mark_boundaries(image, label_img, color, outline_color, mode, background_label)
#     228         outlines = dilation(boundaries, square(3))
#     229         marked[outlines] = outline_color
# --> 230     marked[boundaries] = color
#     231     return marked
#
# ValueError: shape mismatch: value array of shape (3,) could not be broadcast to indexing result of shape (2428,4)

# %%
from skimage.segmentation import slic, mark_boundaries
from skimage.util import img_as_float
from skimage import io
#from skimage.data import lena
#import slic as slic_wrap # code available at https://github.com/amueller/slic-python
import matplotlib.pyplot as plt
from skimage.measure import regionprops


#img = lena()
img = img_as_float(io.imread("greyscale.png"))
ii = slic(img, 40, 10, sigma=1, enforce_connectivity=False)
ii = ii+1
regions = regionprops(ii)
rag = graph.rag_mean_color(img, ii)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-6c694efef34d> in <module>()
#      13 ii = ii+1
#      14 regions = regionprops(ii)
# ---> 15 rag = graph.rag_mean_color(img, ii)
#
# NameError: name 'graph' is not defined
